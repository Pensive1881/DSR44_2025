# %% [markdown]
# <a href="https://colab.research.google.com/github/Pensive1881/DSR44_2025/blob/main/car_image_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install FiftyOne

# %%
# %%capture
# !uv pip install fiftyone==1.9.0

# %%
import os
from google.colab import userdata
FIFTYONE_CVAT_PASSWORD = userdata.get('FIFTYONE_CVAT_PASSWORD')
FIFTYONE_CVAT_USERNAME = userdata.get('FIFTYONE_CVAT_USERNAME')

# %%
# !export FIFTYONE_CVAT_USERNAME={FIFTYONE_CVAT_USERNAME}
# !export FIFTYONE_CVAT_PASSWORD={FIFTYONE_CVAT_PASSWORD}

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
from pathlib import Path
Path('/gdrive/MyDrive/')
# Out:
# PosixPath('/gdrive/MyDrive')

# %% [markdown]
# ## TODO: Create the FiftyOne dataset inside Google Colab
#  Use the script that we used in VSCode as guide.
