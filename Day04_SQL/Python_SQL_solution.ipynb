# %% [markdown]
# <a href="https://colab.research.google.com/github/Pensive1881/DSR44_2025/blob/main/Python_SQL_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import library
import sqlite3
from sqlite3 import Error

# %%
# Connect to an SQLite database; use ':memory:' for an in-memory database
conn = sqlite3.connect(':memory:')

# %%
def execute_query(conn, sql_query):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(sql_query)
    except Error as e:
        print(e)

    # print(f"Returned values: {c.fetchall()[0]}")
    return c.fetchall()

# %%
# THE TASK
# Import the Titanic Dataset

import pandas as pd
import seaborn as sns

# Load the Titanic dataset from seaborn
titanic_df = sns.load_dataset('titanic')

# %%
titanic_df.to_sql(name='titanic', con=conn)
# Out:
# 891

# %%
execute_query(conn, "SELECT * FROM titanic")
# Out:
# [(0,
#   0,
#   3,
#   'male',
#   22.0,
#   1,
#   0,
#   7.25,
#   'S',
#   'Third',
#   'man',
#   1,
#   None,
#   'Southampton',
#   'no',
#   0),
#  (1,
#   1,
#   1,
#   'female',
#   38.0,
#   1,
#   0,
#   71.2833,
#   'C',
#   'First',
#   'woman',
#   0,
#   'C',
#   'Cherbourg',
#   'yes',
#   0),
#  (2,
#   1,
#   3,
#   'female',
#   26.0,
#   0,
#   0,
#   7.925,
#   'S',
#   'Third',
#   'woman',
#   0,
#   None,
#   'Southampton',
#   'yes',
#   1),
#  (3,
#   1,
#   1,
#   'female',
#   35.0,
#   1,
#   0,
#   53.1,
#   'S',
#   'First',
#   'woman',
#   0,
#   'C',
#   'Southampton',
#   'yes',
#   0),
#  (4,
#   0,
#   3,
#   'male',
#   35.0,
#   0,
#   0,
#   8.05,
#   'S',
#   'Third',
#   'man',
#   1,
#   None,
#   'Southampton',
#   'no',
#   1),
#  (5,
#   0,
#   3,
#   'male',
#   None,
#   0,
#   0,
#   8.4583,
#   'Q',
#   'Third',
#   'man',
#   1,
#   None,
#   'Queenstown',
#   'no',
#   1),
#  (6,
#   0,
#   1,
#   'male',
#   54.0,
#   0,
#   0,
# ...

# %%
execute_query(conn, "Select 100 * sum(survived)/count(survived) FROM titanic")
# Out:
# [(38,)]

# %%
execute_query(conn, "SELECT count(sex) FROM titanic where sex='male'")
# Out:
# [(577,)]

# %%
execute_query(conn, "SELECT count(sex) FROM titanic where sex='female'")
# Out:
# [(314,)]

# %%
execute_query(conn, "SELECT count(sex) FROM titanic where survived=0")
# Out:
# [(549,)]

# %%
# WHAT IS THE PERCENTAGE OF UNACCOMPANIED MINORS?
execute_query(conn,"SELECT 100.0*count(survived)/(SELECT count(*) FROM titanic) FROM titanic WHERE age<18 AND alone=True")
# Out:
# [(2.5813692480359145,)]

# %%
execute_query(conn,"""SELECT COUNT(*) FROM (SELECT * FROM titanic ORDER BY fare ASC LIMIT 89) WHERE survived=1""")
# Out:
# [(12,)]
