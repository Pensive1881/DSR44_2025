# %% [markdown]
# <a href="https://colab.research.google.com/github/Pensive1881/DSR44_2025/blob/main/3_NodeClassificationPyG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Downgrade torch to install PyG (ignore the pip error because we won't use those packages)
# !pip uninstall -y torch torchaudio torchvision
# !pip install -q torch==2.8.0 --index-url https://download.pytorch.org/whl/cu126
# Out:
# Found existing installation: torch 2.9.0+cu126
# Uninstalling torch-2.9.0+cu126:
#   Successfully uninstalled torch-2.9.0+cu126
# Found existing installation: torchaudio 2.9.0+cu126
# Uninstalling torchaudio-2.9.0+cu126:
#   Successfully uninstalled torchaudio-2.9.0+cu126
# Found existing installation: torchvision 0.24.0+cu126
# Uninstalling torchvision-0.24.0+cu126:
#   Successfully uninstalled torchvision-0.24.0+cu126
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.8/821.8 MB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 7.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.8.5 requires torchvision>=0.11, which is not installed.
# timm 1.0.22 requires torchvision, which is not installed.

# %%
# Please, make a copy of the notebook before we start.
# Turn on the GPU support in the Runtime/Change runtime type.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# Install Pytorch Geometric and its dependencies
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()

def visualize_both(h1, h2, title1, title2, color):
    z1 = TSNE(n_components=2).fit_transform(h1.detach().cpu().numpy())
    z2 = TSNE(n_components=2).fit_transform(h2.detach().cpu().numpy())

    fig, ax = plt.subplots(1, 2, figsize=(20, 10))

    ax[0].scatter(z1[:, 0], z1[:, 1], s=70, c=color, cmap="Set2")
    ax[0].set_title(title1)
    ax[0].set_xticks([])
    ax[0].set_yticks([])

    ax[1].scatter(z2[:, 0], z2[:, 1], s=70, c=color, cmap="Set2")
    ax[1].set_title(title2)
    ax[1].set_xticks([])
    ax[1].set_yticks([])

    plt.show()
# Out:
# 2.8.0+cu126
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 77.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 67.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for torch-geometric (pyproject.toml) ... done

# %% [markdown]
# # **Transductive & Inductive learning on graphs**
#
# >"[Transductive inference](https://en.wikipedia.org/wiki/Transduction_(machine_learning)) is reasoning from observed, specific (training) cases to specific (test) cases." \
# >Inductive inference "is reasoning from observed training cases to general rules, which are then applied to the test cases."
#
# What does it actually mean?
#
#
# <center width="100%" style="padding:10px"> <img src ="https://drive.google.com/uc?id=1IkDcHZ9x0mdBsiFiLjHlgoykThitQyMi" width="600px"></center>
#
#
# Inductive inference  | Transductive inference
# -------------------|------------------
# Train the model and label unlabelled points which we **have never encountered**. | Train the model and label unlabelled points which we **have already encountered**.
# **Use the initially trained model** for prediction of new unlabelled points. | **Retrain the model** to predict new unlabelled points.
# Can predict **any point** in the feature space. | Can predict **only the points encountered in the test dataset**.
# **Less** computational costs. | Can become **more** computationally costly.

# %% [markdown]
# #### **GCN layer revisited**
#
# Let's have a look at the GCN layer one more time:
# * $\hat A = A + I$ - sum of the adjacency matrix and an identity matrix. $\hat A \in R^{N \times N}$
# * $\hat D$ - a diagonal node degree matrix of $\hat A$.
#
# $$H^{l+1} = \sigma\left(\hat{D}^{-1/2}\hat{A}\hat{D}^{-1/2}H^{l}W^{l}\right)$$
#
# **The adjacency matrix is inside the formula of the update rule!**
#
# **<font color='red'>The nature of the GCN layer is that it only* works in the transductive setting.</font>**
#
# Consequences:
#
# *   It's impossible to classify a newly added node without retraining the model, since the size of the adjacency matrix would change.
# *   Even if we use the trained model with the graph of the same size the predictions would be meaningless, since the adjacency matrix would contain different entries.
#
# **What do we need to do to be able to use a trained model with a completely different graph?**
#
# *   Implement the GCN layer in a form that allows to use inductive learning**. (Check PyG implementations).
# *   Use differrent algorithms, e.g. [generalized message passing algorithm from DeepMind](https://arxiv.org/abs/1806.01261). We will do it in the next colab.
#
#
# \* It depends on the implementation. PyG implementation allows it to work in the inductive setting out of the box. \
# \** It's not guaranteed that the results on the unseen data would be any good because of the nature of graph convolutions that can be represented as polynomial functions of the adjacency matrix. Explanations: [Graph Representation Learing: Chapter 7](https://www.cs.mcgill.ca/~wlh/grl_book/)

# %% [markdown]
# # **PyTorch Geometric: Introduction via Node Classification**
#
# *   Implementing GNNs with an adjacency matrix is simple and straightforward but can be computationally expensive for large graphs.
# *   **[PyTorch Geometric (PyG) library](https://github.com/rusty1s/pytorch_geometric)** is an extension to PyTorch, and consists of various methods and utilities for optimized and easy implementation of GNNs.
#
# #### **Dataset**
# PyTorch Geometric provides an easy access to the dataset via the [`torch_geometric.datasets`](https://pytorch-geometric.readthedocs.io/en/latest/modules/datasets.html#torch_geometric.datasets) subpackage.

# %%
from torch_geometric.datasets import Planetoid

dataset = Planetoid(root='data/Planetoid', name='Cora')
print(f'Dataset: {dataset}:')
print('=========================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Dataset: Cora():
# =========================
# Number of graphs: 1
# Number of features: 1433
# Number of classes: 7
# Processing...
# Done!

# %% [markdown]
# We will use `Cora` dataset, which is a **citation network** where nodes represent documents. Each node is described by a 1433-dimensional bag-of-words feature vector. Two documents are connected if there exists a citation link between them.

# %% [markdown]
# We can extract the first (and the only) graph, represented by PyG class [Data](https://pytorch-geometric.readthedocs.io/en/latest/modules/data.html#torch_geometric.data.Data), from the dataset object and gather some statistics about it.

# %%
data = dataset[0]  # Get the first graph object.

print(data)
print('==============================================================')

# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {(data.num_edges) / (2 * data.num_nodes):.2f}')
print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
print(f'Contains isolated nodes: {data.has_isolated_nodes()}')
print(f'Contains self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# ==============================================================
# Number of nodes: 2708
# Number of edges: 10556
# Average node degree: 1.95
# Number of training nodes: 140
# Training node label rate: 0.05
# Contains isolated nodes: False
# Contains self-loops: False
# Is undirected: True

# %% [markdown]
# The `train_mask`, `val_mask`, and `test_mask` are boolean masks that indicate which nodes we should use for training, validation, and testing

# %% [markdown]
# #### **Edge index**
#
# *   We represent node connectivity via the `edge_index` tensor.
# *   Printing its transposed version shows us the edges between nodes, e.g. $[0, 633]$ means that there's an edge between node $0$ and node $633$.
# *   The edge is shown twice for an undirected graph, but the positions of its values are switched, e.g. $[633, 0]$.
# *   If a graph is directed, then there is an edge only one edge corresponding to each edge direction, e.g. $[0, 633]$ **only**.

# %%
from IPython.display import Javascript  # Restrict height of output cell.

display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))
edge_index = data.edge_index
print(edge_index.t()[:100])
# Out:
# tensor([[ 633,    0],
#         [1862,    0],
#         [2582,    0],
#         [   2,    1],
#         [ 652,    1],
#         [ 654,    1],
#         [   1,    2],
#         [ 332,    2],
#         [1454,    2],
#         [1666,    2],
#         [1986,    2],
#         [2544,    3],
#         [1016,    4],
#         [1256,    4],
#         [1761,    4],
#         [2175,    4],
#         [2176,    4],
#         [1629,    5],
#         [1659,    5],
#         [2546,    5],
#         [ 373,    6],
#         [1042,    6],
#         [1416,    6],
#         [1602,    6],
#         [ 208,    7],
#         [ 269,    8],
#         [ 281,    8],
#         [1996,    8],
#         [ 723,    9],
#         [2614,    9],
#         [ 476,   10],
#         [2545,   10],
#         [1655,   11],
#         [1839,   11],
#         [1001,   12],
#         [1318,   12],
#         [2661,   12],
#         [2662,   12],
#         [1701,   13],
#         [1810,   13],
#         [ 158,   14],
#         [2034,   14],
#         [2075,   14],
#         [2077,   14],
#         [2668,   14],
#         [1090,   15],
#         [1093,   15],
#         [1271,   15],
#         [2367,   15],
#         [ 970,   16],
#         [1632,   16],
#         [2444,   16],
#         [2642,   16],
#         [  24,   17],
#         [ 927,   17],
#         [1315,   17],
#         [1316,   17],
#         [2140,   17],
#         [ 139,   18],
#         [1560,   18],
#         [1786,   18],
#         [2082,   18],
#         [2145,   18],
#         [1939,   19],
#         [1072,   20],
#         [2269,   20],
#         [2270,   20],
#         [2374,   20],
#         [2375,   20],
#         [1043,   21],
#         [2310,   21],
#         [  39,   22],
#         [1234,   22],
#         [1702,   22],
#         [1703,   22],
#         [2238,   22],
#         [2159,   23],
#         [  17,   24],
#         [ 201,   24],
#         [ 598,   24],
#         [1636,   24],
#         [1701,   24],
#         [2139,   24],
#         [2141,   24],
#         [1301,   25],
#         [1344,   25],
#         [2011,   25],
#         [2317,   25],
#         [  99,   26],
#         [ 122,   26],
#         [ 123,   26],
#         [2454,   26],
#         [2455,   26],
#         [ 606,   27],
#         [1810,   27],
#         [2360,   27],
#         [2578,   27],
#         [1687,   28],
#         [ 963,   29],
#         [2645,   29]])

# %% [markdown]
# This representation is known as the **COO format (coordinate format)** commonly used for representing sparse matrices.

# %% [markdown]
# ## **Node classification**
#
# The task is to infer the category of each document (7 in total), having only a small fraction, 5%, of labeled nodes in the training set.
#
# Let's create an MLP baseline that is applied to each node independently. This way we can verify whether adding the graph information to the model indeed improves the prediction or not. However, it might also be that the features per node are already expressive enough to clearly point towards a specific class.

# %%
from torch.nn import Linear, Dropout, ReLU

class MLP(torch.nn.Module):
    def __init__(self, c_in, c_out, c_hidden):
        super().__init__()
        torch.manual_seed(12345)
        self.lin1 = Linear(c_in, c_hidden)
        self.lin2 = Linear(c_hidden, c_out)
        self.dropout = Dropout(p=0.5, inplace=False)

    def forward(self, x):
        x = self.lin1(x)
        x = ReLU()(x)
        x = self.dropout(x)
        return self.lin2(x)

c_in = dataset.num_features
c_out = dataset.num_classes
model = MLP(c_in=c_in, c_out=c_out, c_hidden=16)
print(model)
# Out:
# MLP(
#   (lin1): Linear(in_features=1433, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %% [markdown]
# We can visualize the 7-dimensional node embeddings that out untrained model produces, using the [TSNE](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html) package that projects a high-dimensional data onto a low-dimensional plane in such a way that similar points are put close to each other.

# %%
model.eval()

out = model(data.x)
visualize(out, color=data.y)

# %% [markdown]
# **As expected, the untrained model fails to separate the classes and produces similar embeddings for all 7 paper categories.**

# %% [markdown]
# Let's train the MLP model:

# %%
from IPython.display import Javascript  # Restrict height of output cell.
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

#TODO: train MLP
c_in = dataset.num_features
c_out = dataset.num_classes
mlp_model = MLP(c_in=c_in, c_out=c_out, c_hidden=16)

loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(mlp_model.parameters(), lr=0.01, weight_decay=5e-4)

def train():
    mlp_model.train()
    optimizer.zero_grad
    out = mlp_model(data.x)
    loss = loss_function(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return loss

def test(mask):
    mlp_model.eval()
    with torch.no_grad():
        out = mlp_model(data.x)
        pred = out.argmax(dim=1)
        correct = pred[mask] == data.y[mask]
        acc = int(correct.sum()) / int(mask.sum())
    return acc

# %%
for epoch in range(200):
    train()
    train_acc = test(data.train_mask)
    val_acc = test(data.val_mask)
    test_acc = test(data.test_mask)

    print(
        f"Epoch: {epoch}, Train acc: {train_acc:.4f}, "
        f"Val acc: {val_acc:.4f}, Test acc: {test_acc:.4f}"
    )
# Out:
# Epoch: 0, Train acc: 0.2714, Val acc: 0.1340, Test acc: 0.1250
# Epoch: 1, Train acc: 0.4571, Val acc: 0.1520, Test acc: 0.1500
# Epoch: 2, Train acc: 0.6571, Val acc: 0.2300, Test acc: 0.2190
# Epoch: 3, Train acc: 0.7857, Val acc: 0.2840, Test acc: 0.2790
# Epoch: 4, Train acc: 0.8429, Val acc: 0.3480, Test acc: 0.3120
# Epoch: 5, Train acc: 0.9071, Val acc: 0.3940, Test acc: 0.3650
# Epoch: 6, Train acc: 0.9214, Val acc: 0.4300, Test acc: 0.4230
# Epoch: 7, Train acc: 0.9429, Val acc: 0.4520, Test acc: 0.4450
# Epoch: 8, Train acc: 0.9571, Val acc: 0.4760, Test acc: 0.4550
# Epoch: 9, Train acc: 0.9571, Val acc: 0.4780, Test acc: 0.4670
# Epoch: 10, Train acc: 0.9571, Val acc: 0.4880, Test acc: 0.4740
# Epoch: 11, Train acc: 0.9643, Val acc: 0.4980, Test acc: 0.4760
# Epoch: 12, Train acc: 0.9786, Val acc: 0.5060, Test acc: 0.4860
# Epoch: 13, Train acc: 0.9714, Val acc: 0.5120, Test acc: 0.4870
# Epoch: 14, Train acc: 0.9714, Val acc: 0.5060, Test acc: 0.4920
# Epoch: 15, Train acc: 0.9714, Val acc: 0.5060, Test acc: 0.4990
# Epoch: 16, Train acc: 0.9786, Val acc: 0.5100, Test acc: 0.5080
# Epoch: 17, Train acc: 0.9857, Val acc: 0.5140, Test acc: 0.5080
# Epoch: 18, Train acc: 0.9929, Val acc: 0.5180, Test acc: 0.5160
# Epoch: 19, Train acc: 0.9929, Val acc: 0.5220, Test acc: 0.5150
# Epoch: 20, Train acc: 1.0000, Val acc: 0.5180, Test acc: 0.5150
# Epoch: 21, Train acc: 1.0000, Val acc: 0.5160, Test acc: 0.5180
# Epoch: 22, Train acc: 1.0000, Val acc: 0.5300, Test acc: 0.5110
# Epoch: 23, Train acc: 1.0000, Val acc: 0.5320, Test acc: 0.5070
# Epoch: 24, Train acc: 1.0000, Val acc: 0.5380, Test acc: 0.5040
# Epoch: 25, Train acc: 1.0000, Val acc: 0.5320, Test acc: 0.5050
# Epoch: 26, Train acc: 1.0000, Val acc: 0.5380, Test acc: 0.5030
# Epoch: 27, Train acc: 1.0000, Val acc: 0.5400, Test acc: 0.5000
# Epoch: 28, Train acc: 1.0000, Val acc: 0.5400, Test acc: 0.4960
# Epoch: 29, Train acc: 1.0000, Val acc: 0.5420, Test acc: 0.4960
# Epoch: 30, Train acc: 1.0000, Val acc: 0.5380, Test acc: 0.4930
# Epoch: 31, Train acc: 1.0000, Val acc: 0.5380, Test acc: 0.4890
# Epoch: 32, Train acc: 1.0000, Val acc: 0.5340, Test acc: 0.4800
# Epoch: 33, Train acc: 1.0000, Val acc: 0.5280, Test acc: 0.4760
# Epoch: 34, Train acc: 1.0000, Val acc: 0.5180, Test acc: 0.4730
# Epoch: 35, Train acc: 1.0000, Val acc: 0.5120, Test acc: 0.4760
# Epoch: 36, Train acc: 1.0000, Val acc: 0.5140, Test acc: 0.4730
# Epoch: 37, Train acc: 1.0000, Val acc: 0.5140, Test acc: 0.4710
# Epoch: 38, Train acc: 1.0000, Val acc: 0.5180, Test acc: 0.4740
# Epoch: 39, Train acc: 1.0000, Val acc: 0.5220, Test acc: 0.4730
# Epoch: 40, Train acc: 1.0000, Val acc: 0.5240, Test acc: 0.4820
# Epoch: 41, Train acc: 1.0000, Val acc: 0.5280, Test acc: 0.4850
# Epoch: 42, Train acc: 1.0000, Val acc: 0.5240, Test acc: 0.4960
# Epoch: 43, Train acc: 1.0000, Val acc: 0.5260, Test acc: 0.4940
# Epoch: 44, Train acc: 1.0000, Val acc: 0.5320, Test acc: 0.5000
# Epoch: 45, Train acc: 1.0000, Val acc: 0.5320, Test acc: 0.5000
# Epoch: 46, Train acc: 1.0000, Val acc: 0.5340, Test acc: 0.5000
# Epoch: 47, Train acc: 1.0000, Val acc: 0.5400, Test acc: 0.5030
# Epoch: 48, Train acc: 1.0000, Val acc: 0.5520, Test acc: 0.5020
# Epoch: 49, Train acc: 1.0000, Val acc: 0.5540, Test acc: 0.5070
# Epoch: 50, Train acc: 1.0000, Val acc: 0.5520, Test acc: 0.5070
# Epoch: 51, Train acc: 1.0000, Val acc: 0.5600, Test acc: 0.5140
# Epoch: 52, Train acc: 1.0000, Val acc: 0.5540, Test acc: 0.5170
# Epoch: 53, Train acc: 1.0000, Val acc: 0.5540, Test acc: 0.5200
# Epoch: 54, Train acc: 1.0000, Val acc: 0.5580, Test acc: 0.5220
# Epoch: 55, Train acc: 1.0000, Val acc: 0.5500, Test acc: 0.5230
# Epoch: 56, Train acc: 1.0000, Val acc: 0.5480, Test acc: 0.5200
# Epoch: 57, Train acc: 1.0000, Val acc: 0.5440, Test acc: 0.5130
# Epoch: 58, Train acc: 1.0000, Val acc: 0.5420, Test acc: 0.5070
# Epoch: 59, Train acc: 1.0000, Val acc: 0.5360, Test acc: 0.5070
# Epoch: 60, Train acc: 1.0000, Val acc: 0.5380, Test acc: 0.4990
# Epoch: 61, Train acc: 1.0000, Val acc: 0.5380, Test acc: 0.4990
# Epoch: 62, Train acc: 1.0000, Val acc: 0.5300, Test acc: 0.4960
# Epoch: 63, Train acc: 1.0000, Val acc: 0.5220, Test acc: 0.4960
# Epoch: 64, Train acc: 1.0000, Val acc: 0.5220, Test acc: 0.4910
# Epoch: 65, Train acc: 1.0000, Val acc: 0.5220, Test acc: 0.4890
# Epoch: 66, Train acc: 1.0000, Val acc: 0.5220, Test acc: 0.4850
# Epoch: 67, Train acc: 1.0000, Val acc: 0.5120, Test acc: 0.4820
# Epoch: 68, Train acc: 1.0000, Val acc: 0.5120, Test acc: 0.4780
# Epoch: 69, Train acc: 1.0000, Val acc: 0.5100, Test acc: 0.4760
# Epoch: 70, Train acc: 1.0000, Val acc: 0.5100, Test acc: 0.4710
# Epoch: 71, Train acc: 1.0000, Val acc: 0.5100, Test acc: 0.4720
# Epoch: 72, Train acc: 1.0000, Val acc: 0.5020, Test acc: 0.4690
# Epoch: 73, Train acc: 1.0000, Val acc: 0.5000, Test acc: 0.4680
# Epoch: 74, Train acc: 1.0000, Val acc: 0.4960, Test acc: 0.4710
# Epoch: 75, Train acc: 1.0000, Val acc: 0.4920, Test acc: 0.4720
# Epoch: 76, Train acc: 1.0000, Val acc: 0.4920, Test acc: 0.4660
# Epoch: 77, Train acc: 1.0000, Val acc: 0.4920, Test acc: 0.4670
# Epoch: 78, Train acc: 1.0000, Val acc: 0.4820, Test acc: 0.4700
# Epoch: 79, Train acc: 1.0000, Val acc: 0.4820, Test acc: 0.4680
# Epoch: 80, Train acc: 1.0000, Val acc: 0.4780, Test acc: 0.4700
# Epoch: 81, Train acc: 1.0000, Val acc: 0.4780, Test acc: 0.4620
# Epoch: 82, Train acc: 1.0000, Val acc: 0.4760, Test acc: 0.4650
# Epoch: 83, Train acc: 1.0000, Val acc: 0.4760, Test acc: 0.4650
# Epoch: 84, Train acc: 1.0000, Val acc: 0.4800, Test acc: 0.4620
# Epoch: 85, Train acc: 1.0000, Val acc: 0.4780, Test acc: 0.4620
# Epoch: 86, Train acc: 1.0000, Val acc: 0.4780, Test acc: 0.4660
# Epoch: 87, Train acc: 1.0000, Val acc: 0.4760, Test acc: 0.4650
# Epoch: 88, Train acc: 1.0000, Val acc: 0.4740, Test acc: 0.4630
# Epoch: 89, Train acc: 1.0000, Val acc: 0.4820, Test acc: 0.4640
# Epoch: 90, Train acc: 1.0000, Val acc: 0.4840, Test acc: 0.4670
# Epoch: 91, Train acc: 1.0000, Val acc: 0.4900, Test acc: 0.4690
# Epoch: 92, Train acc: 1.0000, Val acc: 0.4920, Test acc: 0.4710
# Epoch: 93, Train acc: 1.0000, Val acc: 0.4940, Test acc: 0.4680
# Epoch: 94, Train acc: 1.0000, Val acc: 0.5020, Test acc: 0.4700
# Epoch: 95, Train acc: 1.0000, Val acc: 0.5060, Test acc: 0.4780
# Epoch: 96, Train acc: 1.0000, Val acc: 0.5160, Test acc: 0.4860
# Epoch: 97, Train acc: 1.0000, Val acc: 0.5100, Test acc: 0.4900
# Epoch: 98, Train acc: 1.0000, Val acc: 0.5100, Test acc: 0.4910
# Epoch: 99, Train acc: 1.0000, Val acc: 0.5100, Test acc: 0.4950
# Epoch: 100, Train acc: 1.0000, Val acc: 0.5140, Test acc: 0.4930
# Epoch: 101, Train acc: 1.0000, Val acc: 0.5060, Test acc: 0.4910
# Epoch: 102, Train acc: 1.0000, Val acc: 0.5000, Test acc: 0.4880
# Epoch: 103, Train acc: 1.0000, Val acc: 0.5020, Test acc: 0.4880
# Epoch: 104, Train acc: 1.0000, Val acc: 0.5040, Test acc: 0.4830
# Epoch: 105, Train acc: 1.0000, Val acc: 0.5000, Test acc: 0.4840
# Epoch: 106, Train acc: 1.0000, Val acc: 0.5060, Test acc: 0.4830
# Epoch: 107, Train acc: 1.0000, Val acc: 0.5040, Test acc: 0.4840
# Epoch: 108, Train acc: 1.0000, Val acc: 0.5100, Test acc: 0.4880
# Epoch: 109, Train acc: 1.0000, Val acc: 0.5120, Test acc: 0.4860
# Epoch: 110, Train acc: 1.0000, Val acc: 0.5080, Test acc: 0.4810
# Epoch: 111, Train acc: 1.0000, Val acc: 0.5100, Test acc: 0.4760
# Epoch: 112, Train acc: 1.0000, Val acc: 0.5160, Test acc: 0.4720
# Epoch: 113, Train acc: 1.0000, Val acc: 0.5120, Test acc: 0.4700
# Epoch: 114, Train acc: 1.0000, Val acc: 0.5060, Test acc: 0.4680
# Epoch: 115, Train acc: 1.0000, Val acc: 0.5060, Test acc: 0.4670
# Epoch: 116, Train acc: 1.0000, Val acc: 0.5080, Test acc: 0.4660
# Epoch: 117, Train acc: 1.0000, Val acc: 0.5040, Test acc: 0.4640
# Epoch: 118, Train acc: 1.0000, Val acc: 0.5000, Test acc: 0.4590
# Epoch: 119, Train acc: 1.0000, Val acc: 0.4980, Test acc: 0.4570
# Epoch: 120, Train acc: 1.0000, Val acc: 0.4960, Test acc: 0.4590
# Epoch: 121, Train acc: 1.0000, Val acc: 0.4960, Test acc: 0.4590
# Epoch: 122, Train acc: 1.0000, Val acc: 0.4880, Test acc: 0.4530
# Epoch: 123, Train acc: 1.0000, Val acc: 0.4860, Test acc: 0.4520
# Epoch: 124, Train acc: 1.0000, Val acc: 0.4860, Test acc: 0.4470
# Epoch: 125, Train acc: 1.0000, Val acc: 0.4820, Test acc: 0.4440
# Epoch: 126, Train acc: 1.0000, Val acc: 0.4840, Test acc: 0.4430
# Epoch: 127, Train acc: 1.0000, Val acc: 0.4840, Test acc: 0.4380
# Epoch: 128, Train acc: 1.0000, Val acc: 0.4820, Test acc: 0.4350
# Epoch: 129, Train acc: 1.0000, Val acc: 0.4720, Test acc: 0.4270
# Epoch: 130, Train acc: 1.0000, Val acc: 0.4760, Test acc: 0.4280
# Epoch: 131, Train acc: 1.0000, Val acc: 0.4760, Test acc: 0.4270
# Epoch: 132, Train acc: 1.0000, Val acc: 0.4720, Test acc: 0.4310
# Epoch: 133, Train acc: 1.0000, Val acc: 0.4640, Test acc: 0.4270
# Epoch: 134, Train acc: 1.0000, Val acc: 0.4600, Test acc: 0.4280
# Epoch: 135, Train acc: 1.0000, Val acc: 0.4600, Test acc: 0.4270
# Epoch: 136, Train acc: 1.0000, Val acc: 0.4560, Test acc: 0.4290
# Epoch: 137, Train acc: 1.0000, Val acc: 0.4520, Test acc: 0.4260
# Epoch: 138, Train acc: 1.0000, Val acc: 0.4480, Test acc: 0.4270
# Epoch: 139, Train acc: 1.0000, Val acc: 0.4480, Test acc: 0.4210
# Epoch: 140, Train acc: 1.0000, Val acc: 0.4460, Test acc: 0.4210
# Epoch: 141, Train acc: 1.0000, Val acc: 0.4500, Test acc: 0.4210
# Epoch: 142, Train acc: 1.0000, Val acc: 0.4480, Test acc: 0.4190
# Epoch: 143, Train acc: 1.0000, Val acc: 0.4440, Test acc: 0.4220
# Epoch: 144, Train acc: 0.9929, Val acc: 0.4420, Test acc: 0.4250
# Epoch: 145, Train acc: 0.9929, Val acc: 0.4420, Test acc: 0.4220
# Epoch: 146, Train acc: 0.9929, Val acc: 0.4420, Test acc: 0.4230
# Epoch: 147, Train acc: 0.9929, Val acc: 0.4380, Test acc: 0.4290
# Epoch: 148, Train acc: 0.9929, Val acc: 0.4440, Test acc: 0.4330
# Epoch: 149, Train acc: 0.9929, Val acc: 0.4380, Test acc: 0.4300
# Epoch: 150, Train acc: 0.9929, Val acc: 0.4400, Test acc: 0.4300
# Epoch: 151, Train acc: 0.9929, Val acc: 0.4440, Test acc: 0.4340
# Epoch: 152, Train acc: 1.0000, Val acc: 0.4420, Test acc: 0.4400
# Epoch: 153, Train acc: 1.0000, Val acc: 0.4300, Test acc: 0.4380
# Epoch: 154, Train acc: 1.0000, Val acc: 0.4260, Test acc: 0.4410
# Epoch: 155, Train acc: 1.0000, Val acc: 0.4220, Test acc: 0.4390
# Epoch: 156, Train acc: 1.0000, Val acc: 0.4340, Test acc: 0.4410
# Epoch: 157, Train acc: 1.0000, Val acc: 0.4240, Test acc: 0.4400
# Epoch: 158, Train acc: 1.0000, Val acc: 0.4180, Test acc: 0.4420
# Epoch: 159, Train acc: 1.0000, Val acc: 0.4160, Test acc: 0.4370
# Epoch: 160, Train acc: 1.0000, Val acc: 0.4100, Test acc: 0.4290
# Epoch: 161, Train acc: 1.0000, Val acc: 0.4040, Test acc: 0.4270
# Epoch: 162, Train acc: 1.0000, Val acc: 0.4040, Test acc: 0.4270
# Epoch: 163, Train acc: 1.0000, Val acc: 0.4020, Test acc: 0.4270
# Epoch: 164, Train acc: 1.0000, Val acc: 0.4060, Test acc: 0.4240
# Epoch: 165, Train acc: 1.0000, Val acc: 0.4020, Test acc: 0.4240
# Epoch: 166, Train acc: 1.0000, Val acc: 0.3920, Test acc: 0.4240
# Epoch: 167, Train acc: 1.0000, Val acc: 0.3900, Test acc: 0.4180
# Epoch: 168, Train acc: 1.0000, Val acc: 0.3840, Test acc: 0.4150
# Epoch: 169, Train acc: 1.0000, Val acc: 0.3860, Test acc: 0.4170
# Epoch: 170, Train acc: 1.0000, Val acc: 0.3820, Test acc: 0.4090
# Epoch: 171, Train acc: 1.0000, Val acc: 0.3800, Test acc: 0.4050
# Epoch: 172, Train acc: 1.0000, Val acc: 0.3780, Test acc: 0.4010
# Epoch: 173, Train acc: 1.0000, Val acc: 0.3760, Test acc: 0.3970
# Epoch: 174, Train acc: 1.0000, Val acc: 0.3760, Test acc: 0.3930
# Epoch: 175, Train acc: 1.0000, Val acc: 0.3700, Test acc: 0.3930
# Epoch: 176, Train acc: 1.0000, Val acc: 0.3700, Test acc: 0.3910
# Epoch: 177, Train acc: 1.0000, Val acc: 0.3700, Test acc: 0.3930
# Epoch: 178, Train acc: 1.0000, Val acc: 0.3700, Test acc: 0.3900
# Epoch: 179, Train acc: 1.0000, Val acc: 0.3740, Test acc: 0.3890
# Epoch: 180, Train acc: 1.0000, Val acc: 0.3740, Test acc: 0.3850
# Epoch: 181, Train acc: 1.0000, Val acc: 0.3740, Test acc: 0.3810
# Epoch: 182, Train acc: 1.0000, Val acc: 0.3740, Test acc: 0.3780
# Epoch: 183, Train acc: 1.0000, Val acc: 0.3680, Test acc: 0.3790
# Epoch: 184, Train acc: 1.0000, Val acc: 0.3660, Test acc: 0.3800
# Epoch: 185, Train acc: 1.0000, Val acc: 0.3660, Test acc: 0.3780
# Epoch: 186, Train acc: 1.0000, Val acc: 0.3640, Test acc: 0.3760
# Epoch: 187, Train acc: 1.0000, Val acc: 0.3660, Test acc: 0.3740
# Epoch: 188, Train acc: 1.0000, Val acc: 0.3580, Test acc: 0.3700
# Epoch: 189, Train acc: 1.0000, Val acc: 0.3540, Test acc: 0.3660
# Epoch: 190, Train acc: 0.9929, Val acc: 0.3560, Test acc: 0.3680
# Epoch: 191, Train acc: 0.9929, Val acc: 0.3540, Test acc: 0.3680
# Epoch: 192, Train acc: 0.9929, Val acc: 0.3560, Test acc: 0.3720
# Epoch: 193, Train acc: 0.9929, Val acc: 0.3500, Test acc: 0.3740
# Epoch: 194, Train acc: 0.9929, Val acc: 0.3440, Test acc: 0.3780
# Epoch: 195, Train acc: 0.9929, Val acc: 0.3420, Test acc: 0.3720
# Epoch: 196, Train acc: 0.9929, Val acc: 0.3400, Test acc: 0.3720
# Epoch: 197, Train acc: 0.9929, Val acc: 0.3400, Test acc: 0.3700
# Epoch: 198, Train acc: 0.9929, Val acc: 0.3400, Test acc: 0.3680
# Epoch: 199, Train acc: 0.9929, Val acc: 0.3340, Test acc: 0.3660

# %% [markdown]
# **Reasons for poor MLP performance**
#
# *   **Strong overfitting** due to only having access to a **small amount of training nodes**, that leads to poor generalization on the unseen nodes.
# *   It also fails to incorporate an important inductive bias into the model: **Papers belonging to the same category are most likely to have a citation relation (edge) between them** $\to$ we can use a GNN to incorporate this information.

# %%
from torch_geometric.nn import GCNConv

class GCN(torch.nn.Module):
    def __init__(self, c_in, c_out, c_hidden):
      pass

# %% [markdown]
# ### **Exercise 2.1: MLP vs GCN untrained embeddings**
#
# *   Create two new models, MLP and GCN, i.e. instances of the corresponding classes, using the same number of input/hidden/output channels. Please, use `c_hidden=256` for both models and name a new MLP model differently, so the trained model stays untouched, we will need it for later.
# *   Following the example above, plot the lower dimensional representation of the node embeddings produced by the both models.
#   - **hint:** don't forget to set the models to the evaluation mode. This will turn the dropout off.
#   - **hint:** make use of the function `visualize_both` defined in the imports.
# * Answer the following questions:
#   - What is the difference between the embeddings?
#   - Why do you think this difference exists?
#   - What conclusions about GCNs can you draw?

# %% [markdown]
# #### **[The Weisfeiler-Lehman Isomorphism Test](https://davidbieber.com/post/2019-05-10-weisfeiler-lehman-isomorphism-test/)**
#
# <center width="100%" style="padding:10px"> <img src ="https://drive.google.com/uc?id=1ar2xbg4lz0_-AjkT0Ic2EEHZKyXl2Mjl" width="600px"></center>
#
# > "*Two graphs are considered isomorphic if there is a mapping between the nodes of the graphs that preserves node adjacencies.*"
#
# **Algorithm:**
#
# 1.   Intialize all nodes features to 1.
# 2.   Get features $\{ h_{v_j} \}$ of neighboring nodes $\{ v_j \}$
# 3.   Update node feature $h_{v_i} \leftarrow \text{hash} (\sum_j h_{v_j})$
# 4.   Partition the nodes in the graph by their features. Repeat 2 + 3 for up to  (the number of nodes) iterations, or until there is no change in the partition of nodes by features from one iteration to the next.
#
# If the partitions of two graphs are the same, then the graphs can be isomorphic.
#
# *   Graph Convolutional layer-wise propagation rule in vector form:
# $$h_{v_i}^{(l+1)} = \sigma (\sum_j \frac{1}{c_{ij}}  h_{v_j}^{(l)} W^{(l)}),$$
# where $c_{ij}$ is a normalization constant for the edge.
#
# *  The propagation rule can be interpreted as a differentiable and parametrized (with W(l)) variant of the hash function used in the Weisfeiler-Lehman algorithm.
#
# **We get meaningful smooth embeddings where we can interpret distance as (dis-)similarity of local graph structures!**

# %% [markdown]
# ### **Exercise 2.2: Train and visualize GCN**
#
# *   Write code for training the GCN model.
#   - **hint:** Modify the code for MLP training so that it runs with the GCN model.
#   - **hint:** Use the same number of hidden channels.
# *   Compare the results of the GCN and MLP.
# *   Visualize trained embeddings of MLP and GCN.
#   - **hint:** You can reuse the code from Exercise 2.1, you just need to use the trained models. Don't forget to set them to the eval mode.
