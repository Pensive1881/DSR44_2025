# %%
## NOTEBOOK 03 - Subplots
fig = (
    make_subplots(
        rows=2,
        cols=1,
        subplot_titles=('Initial values', 'Final values'),
        shared_xaxes=True,
        vertical_spacing=0.05,
    )
    .add_scatter(
        x=table.Xi,
        y=table.Yi,
        name='Initial',
        row=1,
        col=1,
    )
    .add_scatter(
        x=table.Xf,
        y=table.Yf,
        hovertext=table.color,
        name='Final',
        row=2,
        col=1,
    )
    .update_layout(
        title = 'Random clusters',
        xaxis2_range=[0,500],
        width = 600,
        height = 900,
        showlegend = False,
    )
    .update_xaxes(
        title='X',
        range=[0, 500],
        row=2,
    )
    .update_yaxes(
        title='Y',
        range=[0, 500],
    )
    .update_traces(
        mode='markers',
        marker_color=table.color,
    )
)
