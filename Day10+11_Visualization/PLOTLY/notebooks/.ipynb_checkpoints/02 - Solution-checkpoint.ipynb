# %%
### exercise 1
trace = dict(
    type= 'scatter',
    x= table.Xf,
    y= table.Yf,
    # marker_color=table.color,
    # marker_size=20,
    marker=dict(color=table.color, size=10),
    hovertext=table.color,
    mode= 'markers', # 'lines+markers', 'lines', 'markers'
)

data = [trace]

layout = dict(
    title= 'Random clusters',
    width= 500,
    height= 400,
    xaxis_title='Xf',
    yaxis_title='Yf',
)

fig = go.Figure(
    data=data,
    layout=layout,
)

### exercise 2
trace1 = dict(
    type='histogram',
    x=table.Xi,
    nbinsx=10,
    name='initial',
    # opacity=0.5,
)

trace2 = go.Histogram(
    # type='histogram',
    x=table.Xf,
    nbinsx=10,
    name='final',
)

data = [trace1, trace2]

layout = dict(
    title= 'Histogram of X positions',
    width= 500,
    height= 400,
    xaxis=dict(title='x value'),
    yaxis=dict(title='occurrences'),
    barmode='group' # 'stack', 'overlay'
)

fig = go.Figure(
    data= data,
    layout= layout,
)
