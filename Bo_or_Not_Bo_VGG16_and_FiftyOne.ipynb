# %% [markdown]
# <a href="https://colab.research.google.com/github/Pensive1881/DSR44_2025/blob/main/Bo_or_Not_Bo_VGG16_and_FiftyOne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
pip install fiftyone==1.8.0

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1261173595.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/gdrive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import os
from google.colab import datauser
import kagglehub

# This is set up as an environment variable, it's alive in memory
os.environ['KAGGLE_USERNAME'] = userdata.get['KAGGLE_USERNAME']
os.environ['KAGGLE_KEY'] = userdata.get['KAGGLE_KEY']

# to download the data, we specify the name of the user who published it and the name of the datasert
download_path = kagglehub.dataset_download('andandand/presidential-dog')

# %%
from PIL import Image
pil_img = Image.open('/kaggle/input/presidential_dog/train/bo/boi_10.jpg')
pil_img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3175310057.py in <cell line: 0>()
#       1 from PIL import Image
# ----> 2 pil_img = Image.open('/kaggle/input/presidential_dog/train/bo/boi_10.jpg')
#       3 pil_img
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3511     if is_path(fp):
#    3512         filename = os.fspath(fp)
# -> 3513         fp = builtins.open(filename, "rb")
#    3514         exclusive_fp = True
#    3515     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/presidential_dog/train/bo/boi_10.jpg'

# %%
pretrained_weights = VGG16_Weights.IMAGET1K_V1
dir(pretrained_weights)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1735493552.py in <cell line: 0>()
# ----> 1 pretrained_weights = VGG16_Weights.IMAGET1K_V1
#       2 dir(pretrained_weights)
#
# NameError: name 'VGG16_Weights' is not defined

# %%
original_transformation = pretrained_weights.transforms()
original_transformation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3098313340.py in <cell line: 0>()
# ----> 1 original_transformation = pretrained_weights.transforms()
#       2 original_transformation
#
# NameError: name 'pretrained_weights' is not defined

# %%
pretrained_weights.meta
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3215300368.py in <cell line: 0>()
# ----> 1 pretrained_weights.meta
#
# NameError: name 'pretrained_weights' is not defined

# %%
from torchvision.models importr vgg16 , VGG16_Weights

#Loading a pre-trained VGG16 model
model = vgg16(weights=VGG16_Weights.IMAGENET1K_V1)
model.eval()

# %%
# Here we inspect the frist layer of features
first_layer = model.features[0]

# %%
model.classifier
